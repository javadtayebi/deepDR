# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os
os.chdir('/content/drive/MyDrive/GdeepDR')

# %%
# !pip install pytrec_eval
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for pytrec_eval: filename=pytrec_eval-0.5-cp310-cp310-linux_x86_64.whl size=308204 sha256=a6d95aac93372b53d7fa52beb110da5e8f05c832ec43c6ac0ff4a3a52b876418
#   Stored in directory: /root/.cache/pip/wheels/51/3a/cd/dcc1ddfc763987d5cb237165d8ac249aa98a23ab90f67317a8
# Successfully built pytrec_eval
# ...

# %%
# !python get_features.py params.txt

# %%
# !python models/recommendation/collective_variational_autoencoder.py --dir dataset -a 6 -b 0.1 -m 300 --save --layer 1000 100
# Out:
# dataset directory: dataset
# train data path: dataset/drug_disease.txt
# feature data path: drug_features.txt
# Train Epoch: 1 [0/1000 (0%)]	Loss: 2294.374219
# Train Epoch: 1 [100/1000 (10%)]	Loss: 1573.767969
# Train Epoch: 1 [200/1000 (20%)]	Loss: 518.442695
# Train Epoch: 1 [300/1000 (30%)]	Loss: 118.056260
# Train Epoch: 1 [400/1000 (40%)]	Loss: 181.573027
# Train Epoch: 1 [500/1000 (50%)]	Loss: 235.626172
# Train Epoch: 1 [600/1000 (60%)]	Loss: 246.424043
# Train Epoch: 1 [700/1000 (70%)]	Loss: 228.207949
# Train Epoch: 1 [800/1000 (80%)]	Loss: 194.237148
# Train Epoch: 1 [900/1000 (90%)]	Loss: 155.200303
# ====> Epoch: 1 Average loss: 574.5910
# Train Epoch: 2 [0/1000 (0%)]	Loss: 118.055010
# Train Epoch: 2 [100/1000 (10%)]	Loss: 86.899980
# Train Epoch: 2 [200/1000 (20%)]	Loss: 62.596445
# Train Epoch: 2 [300/1000 (30%)]	Loss: 44.481729
# Train Epoch: 2 [400/1000 (40%)]	Loss: 31.483208
# Train Epoch: 2 [500/1000 (50%)]	Loss: 22.380134
# ...

# %%
# !python models/recommendation/collective_variational_autoencoder.py --dir dataset --rating -a 15 -b 3 -m 5 --load 1 --layer 1000 100

# %%
import pickle
from pprint import pprint

with open('results.pickle', 'rb') as handle:
    results = pickle.load(handle)

for fold in results:
  pprint(results[fold]['recall'])
# Out:
# [0.391031, 0.479081, 0.520846, 0.542682, 0.566009, 0.65173, 0.703229]
# [0.425182, 0.499766, 0.526054, 0.548714, 0.580488, 0.66242, 0.706958]
# [0.409522, 0.465536, 0.502496, 0.52423, 0.554779, 0.631382, 0.682047]
# [0.407233, 0.469213, 0.512917, 0.533208, 0.570032, 0.658, 0.713344]
# [0.409885, 0.49324, 0.536206, 0.558264, 0.59468, 0.669716, 0.722359]
